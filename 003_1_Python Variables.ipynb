# %% [markdown]
# ### <font color="#026D8F">**ตัวแปรในภาษาไพทอน (Python Variables)**

# %% [markdown]
# ### <font color="#026D8F">ตัวแปร (Variables)
#
# ตัวแปรมีไว้สำหรับจัดเก็บข้อมูลหรือพักข้อมูลเอาไว้ชั่วคราวในหน่วยความจำ
#
# เราจะต้องตั้งชื่อให้ตัวแปร เพื่อใช้ชื่อตัวแปรในการอ้างอิงไปยังตำแหน่งข้อมูลในหน่วยความจำนั้น ๆ

# %% [markdown]
# ### <font color="#026D8F">การสร้างตัวแปร (Creating Variables)
# Python ไม่มีคำสั่งประกาศตัวแปร โดยตัวแปรของภาษาไพทอน จะถูกสร้างขึ้นขณะที่มีการกำหนดค่าให้ตัวแปรเลย

# %% [markdown]
# ### <font color="#026D8F">ตัวอย่าง

# %%
x = 4
y = "ดำ"
print(x)
print(y)
# Out:
# 4
# ดำ

# %% [markdown]
# ตอนกำหนดค่าให้ตัวแปรนั้นก็ไม่จำเป็นต้องระบุชนิด (type) ของตัวแปร และเรายังสามารถเปลี่ยนชนิดของตัวแปรได้ภายหลังได้อีกด้วย

# %% [markdown]
# ### <font color="#026D8F">ตัวอย่าง

# %%
x = 4       # ตอนนี้ตัวแปร x มีชนิดของตัวแปรเป็น int
x = "แดง"   # พอกำหนดค่าใหม่ให้ x ตอนนี้ x จะเปลี่ยนชนิดตัวแปรเป็น str ไปโดยอัตโนมัติ
print(x)
# Out:
# แดง

# %% [markdown]
# ### <font color="#026D8F">การเปลี่ยนชนิดของตัวแปร (Casting)
# ถ้าต้องการเปลี่ยนชนิดของตัวแปรให้เป็นชนิดที่ต้องการ สามารถทำได้โดยการ casting โดยใช้ built-in function ของ python ได้เลย

# %% [markdown]
# ### <font color="#026D8F">ตัวอย่าง

# %%
x = str(4)    # x จะกลายเป็น str โดยมีค่าเท่ากับ '4'
y = int(4)    # y จะกลายเป็น int โดยมีค่าเท่ากับ 4
z = float(4)  # z จะกลายเป็น float โดยมีค่า 4.0

# %% [markdown]
# ### <font color="#026D8F">ชนิดของตัวแปร (Get the Type)
#
# สามารถรู้ว่าตัวแปรของเราเป็นตัวแปรชนิดใดได้โดยใช้ฟังก์ชัน `type()`

# %% [markdown]
# ### <font color="#026D8F">ตัวอย่าง

# %%
x = 4
y = "แดง"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ### <font color="#026D8F">Single or Double Quotes?
#
# การประกาศตัวแปร str สามารถใช้ได้ทั้ง **single quotes  ( ' )** หรือ **double quotes  ( " )**:

# %% [markdown]
# ### <font color="#026D8F">ตัวอย่าง

# %%
x = "แดง"
# โค้ดบรรทัดบนจะให้ผลลัพธ์แบบเดียวกับโค้ดบรรทัดล่างนี้
x = 'แดง'

# %% [markdown]
# ### <font color="#026D8F">ตัวพิมพ์ใหญ่-พิมพ์เล็ก มีผลต่อชื่อของตัวแปรไหม (Case-Sensitive)
#
# ตัวแปรที่เขียนด้วยตัวพิมพ์ใหญ่ จะเป็นตัวแปรคนละตัวกับตัวแปรที่เขียนด้วยตัวพิมพ์เล็ก แม้จะใช้ตัวอักษรเดียวกัน เช่น a กับ A ถือเป็นตัวแปรคนละตัวกัน

# %% [markdown]
# ### <font color="#026D8F"> ตัวอย่าง
# ตัวแปร 2 ตัวในตัวอย่างนี้ตั้งชื่อด้วยตัวอักษร a เหมือนกัน แต่พิมพ์ด้วยตัวพิมพ์ใหญ่ :A กับตัวพิมพ์เล็ก: a ภาษาไพทอนจะจัดว่าตัวแปรสองตัวนี้เป็นตัวแปรคนละตัวกัน

# %%
a = 4
A = "ดำ"
# การประกาศตัวแปร A จะไม่เป็นการ overwrite ตัวแปร a เพราะภาษาไพทอนจะถือว่าเป็นตัวแปรคนละตัวกัน
