# %% [markdown]
# ### <font color="lightblue">**Python Operators**

# %% [markdown]
# ### <font color="lightblue">**Python Operators**

# %% [markdown]
# Operators are used to perform operations on variables and values.
#
# In the example below, we use the + operator to add together two values:

# %%
print(10 + 5)
# Out:
# 15

# %% [markdown]
# Python divides the operators in the following groups:
#
# * Arithmetic operators
# * Assignment operators
# * Comparison operators
# * Logical operators
# * Identity operators
# * Membership operators
# * Bitwise operators

# %% [markdown]
# ### <font color="lightblue">**Python Arithmetic Operators**

# %% [markdown]
# Arithmetic operators are used with numeric values to perform common mathematical operations:

# %% [markdown]
# Addition (+)

# %%
x = 5
y = 3

print(x + y)
# Out:
# 8

# %% [markdown]
# Subtraction (-)

# %%
x = 5
y = 3

print(x - y)
# Out:
# 2

# %% [markdown]
# Multiplication (*)

# %%
x = 5
y = 3

print(x * y)
# Out:
# 15

# %% [markdown]
# Division (/)

# %%
x = 5
y = 3

print(x / y)
# Out:
# 1.6666666666666667

# %% [markdown]
# Modulus (%)

# %%
x = 5
y = 3

print(x % y)
# Out:
# 2

# %% [markdown]
# Exponentiation (**)

# %%
x = 5
y = 3

print(x ** y)
# Out:
# 125

# %% [markdown]
# Floor division (//)

# %%
x = 5
y = 3

print(x // y)
# Out:
# 1

# %% [markdown]
# ### <font color="lightblue">**Python Assignment Operators**

# %% [markdown]
# Assignment operators are used to assign values to variables:

# %% [markdown]
# (=)

# %%
x = 5

print(x)
# Out:
# 5

# %% [markdown]
# (+=)

# %%
x = 5

x += 3

print(x)
# Out:
# 8

# %% [markdown]
# (-=)

# %%
x = 5

x -= 3

print(x)
# Out:
# 2

# %% [markdown]
# (*=)

# %%
x = 5

x *= 3

print(x)
# Out:
# 15

# %% [markdown]
# (/=)

# %%
x = 5

x /= 3

print(x)
# Out:
# 1.6666666666666667

# %% [markdown]
# (%=)

# %%
x = 5

x %= 3

print(x)
# Out:
# 2

# %% [markdown]
# (//=)

# %%
x = 5

x //= 3

print(x)
# Out:
# 1

# %% [markdown]
# (**=)

# %%
x = 5

x **= 3

print(x)
# Out:
# 125

# %% [markdown]
# (&=)

# %%
x = 5

x &= 3

print(x)
# Out:
# 1

# %% [markdown]
# (|=)

# %%
x = 5

x |= 3

print(x)
# Out:
# 7

# %% [markdown]
# (^=)

# %%
x = 5

x ^= 3

print(x)
# Out:
# 6

# %% [markdown]
# (>>=)

# %%
x = 5

x >>= 3

print(x)
# Out:
# 0

# %% [markdown]
# (<<=)

# %%
x = 5

x <<= 3

print(x)
# Out:
# 40

# %% [markdown]
# ### <font color="lightblue">**Python Comparison Operators**

# %% [markdown]
# Comparison operators are used to compare two values:

# %% [markdown]
# Equal (==)

# %%
x = 5
y = 3

print(x == y)

# returns False because 5 is not equal to 3
# Out:
# False

# %% [markdown]
# Not equal (!=)

# %%
x = 5
y = 3

print(x != y)

# returns True because 5 is not equal to 3
# Out:
# True

# %% [markdown]
# Greater than (>)

# %%
x = 5
y = 3

print(x > y)

# returns True because 5 is greater than 3
# Out:
# True

# %% [markdown]
# Less than (<)

# %%
x = 5
y = 3

print(x < y)

# returns False because 5 is not less than 3
# Out:
# False

# %% [markdown]
# Greater than or equal to (>=)

# %%
x = 5
y = 3

print(x >= y)

# returns True because five is greater, or equal, to 3
# Out:
# True

# %% [markdown]
# Less than or equal to (<=)

# %%
x = 5
y = 3

print(x <= y)

# returns False because 5 is neither less than or equal to 3
# Out:
# False

# %% [markdown]
# ### <font color="lightblue">**Python Logical Operators**

# %% [markdown]
# Logical operators are used to combine conditional statements:

# %% [markdown]
# And
# (Returns True if both statements are true)

# %%
x = 5

print(x > 3 and x < 10)

# returns True because 5 is greater than 3 AND 5 is less than 10
# Out:
# True

# %% [markdown]
# Or
# (Returns True if one of the statements is true)

# %%
x = 5

print(x > 3 or x < 4)

# returns True because one of the conditions are true (5 is greater than 3, but 5 is not less than 4)
# Out:
# True

# %% [markdown]
# Not
# (Reverse the result, returns False if the result is true)

# %%
x = 5

print(not(x > 3 and x < 10))

# returns False because not is used to reverse the result
# Out:
# False

# %% [markdown]
# ### <font color="lightblue">**Python Identity Operators**

# %% [markdown]
# Identity operators are used to compare the objects, not if they are equal, but if they are actually the same object, with the same memory location:

# %% [markdown]
# Is
# (Returns True if both variables are the same object)

# %%
x = ["apple", "banana"]
y = ["apple", "banana"]
z = x

print(x is z)

# returns True because z is the same object as x

print(x is y)

# returns False because x is not the same object as y, even if they have the same content

print(x == y)

# to demonstrate the difference betweeen "is" and "==": this comparison returns True because x is equal to y
# Out:
# True
# False
# True

# %% [markdown]
# Is not
# (Returns True if both variables are not the same object)

# %%
x = ["apple", "banana"]
y = ["apple", "banana"]
z = x

print(x is not z)

# returns False because z is the same object as x

print(x is not y)

# returns True because x is not the same object as y, even if they have the same content

print(x != y)

# to demonstrate the difference betweeen "is not" and "!=": this comparison returns False because x is equal to y
# Out:
# False
# True
# False

# %% [markdown]
# ### <font color="lightblue">**Python Membership Operators**

# %% [markdown]
# Membership operators are used to test if a sequence is presented in an object:

# %% [markdown]
# In
# (Returns True if a sequence with the specified value is present in the object)

# %%
x = ["apple", "banana"]

print("banana" in x)

# returns True because a sequence with the value "banana" is in the list
# Out:
# True

# %% [markdown]
# Not in
# (Returns True if a sequence with the specified value is not present in the object)

# %%
x = ["apple", "banana"]

print("pineapple" not in x)

# returns True because a sequence with the value "pineapple" is not in the list
# Out:
# True

# %% [markdown]
# ### <font color="lightblue">**Python Bitwise Operators**

# %% [markdown]
# Bitwise operators are used to compare (binary) numbers:
#
# * (&) 	AND:	Sets each bit to 1 if both bits are 1
# * (|)	  OR :	Sets each bit to 1 if one of two bits is 1
# * (^)	  XOR:	Sets each bit to 1 if only one of two bits is 1
# * (~) 	NOT:	Inverts all the bits
# * (<<)	Zero fill left shift:
# Shift left by pushing zeros in from the right and let the left most bits fall off
# * (>>)	Signed right shift:
# Shift right by pushing copies of the leftmost bit in from the left, and let the rightmost bits fall off
